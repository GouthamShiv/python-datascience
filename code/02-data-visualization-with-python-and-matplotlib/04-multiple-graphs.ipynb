# %% [markdown]
# [back](./03-graphing-data.ipynb)
#
# ---
# ## `Showing multiple graphs`
# > Add multiple graphs to a single plot or as subplots
#
# - Plot multiple datasets on the same graph
# - Create multiple subplots

# %%
# Importing matplotlib
from matplotlib import pyplot as plt

# %%
# Creating random data-sets
import random

x = [i for i in range(1, 101)]
y1 = []
y2 = []

for i in range(100):
  y1.append(random.randint(1, 101))
  y2.append(random.randint(1, 101))

# %%
plt.plot(x, y1, 'gx', x, y2, 'ro')
plt.show()

# %%
plt.plot(x, y1, 'g', x, y2, 'r')
plt.show()

# %%
# Subplots - Row wise
# plt.subplot(rows, columns, index)

plt.subplot(2, 1, 1)
plt.title('Graph 1')
plt.plot(x, y1, 'r')

plt.subplot(2, 1, 2)
plt.title('Graph 2')
plt.plot(x, y2, 'g')

# Super title, for the whole graph
plt.suptitle('Red Green Row Graphs')
plt.show()

# %%
# Subplots - Column wise
# plt.subplot(rows, columns, index)

plt.subplot(1, 2, 1)
plt.title('Graph 1')
plt.plot(x, y1, 'r')

plt.subplot(1, 2, 2)
plt.title('Graph 2')
plt.plot(x, y2, 'g')

# Super title, for the whole graph
plt.suptitle('Red Green Column Graphs')
plt.show()

# %% [markdown]
# ---
# [next](./05-different-kinds-of-graphs.ipynb)
